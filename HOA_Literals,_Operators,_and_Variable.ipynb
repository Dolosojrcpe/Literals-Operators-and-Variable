# %% [markdown]
# <a href="https://colab.research.google.com/github/Dolosojrcpe/Literals-Operators-and-Variable/blob/main/HOA_Literals%2C_Operators%2C_and_Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.

# %%
value=5
print(value)
# Out:
# 5

# %% [markdown]
# 2.

# %%
type(value)
# Out:
# int

# %%
3.

# %%
value=5.0
print(value)
# Out:
# 5.0

# %% [markdown]
# 4.

# %%
type(value)
# Out:
# float

# %% [markdown]
# 5.
# a

# %%
value=2+3j
print(value)
# Out:
# (2+3j)

# %%
type(value)
# Out:
# complex

# %% [markdown]
# b

# %%
value='Hello World'
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %% [markdown]
# c

# %%
value="Hello World"
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %% [markdown]
# d

# %%
value=True
print(value)
# Out:
# True

# %%
type(value)
# Out:
# bool

# %% [markdown]
# e

# %%
value=False
print(value)
# Out:
# False

# %%
type(value)
# Out:
# bool

# %% [markdown]
# f

# %%
value=[1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(value)
# Out:
# list

# %% [markdown]
# g

# %%
value=(1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
type(value)
# Out:
# tuple

# %% [markdown]
# h

# %%
value={'name':'Andrew_doloso' }
print(value)
# Out:
# {'name': 'Andrew_doloso'}

# %%
type(value)
# Out:
# dict

# %% [markdown]
# i

# %%
value=None
print(value)
# Out:
# None

# %%
type(value)
# Out:
# NoneType

# %% [markdown]
# 6.

# %%
value=5

# %% [markdown]
# 7.

# %%
value2=-6

# %% [markdown]
# Performing Operations with Python

# %%
print(value+value2)
# Out:
# -1

# %% [markdown]
# 2.
# a

# %%
value, value2=5.0, 6

# %%
print(value+value2)
# Out:
# 11.0

# %% [markdown]
# b

# %%
value, value2=-5, 6.1

# %%
print(value+value2)
# Out:
# 1.0999999999999996

# %% [markdown]
# c

# %%
value, value2="Hello", ' World'

# %%
print(value+value2)
# Out:
# Hello World

# %% [markdown]
# d

# %%
value, value2=[1,2,3], [4,5,6]

# %%
print(value+value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# e

# %%
value, value2=(1,2,3), (4,5,6)

# %%
print(value+value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# f

# %%
value, value2={"name":"Royce"}, {"age":(2)}

# %%
print(value,value2)
# Out:
# {'name': 'Royce'} {'age': 2}

# %% [markdown]
# 3.

# %%
value, value2=30, 4

# %% [markdown]
# a

# %%
print(value*value2)
# Out:
# 120

# %% [markdown]
# b

# %%
print(value2**2)
# Out:
# 16

# %% [markdown]
# c

# %%
print(value2**3)
# Out:
# 64

# %% [markdown]
# d

# %%
print(value*value2+value2**2+1)
# Out:
# 137

# %% [markdown]
# e

# %%
print(value/value2)
# Out:
# 7.5

# %% [markdown]
# f

# %%
print(value%value2)
# Out:
# 2

# %% [markdown]
# Assigning Input Data to a Variable
# Finding a person’s BMI (metric)
#
#
#
#
#
#
# 1-5

# %%
name=input("Enter your name: ")
weight=input("Enter your weight(kg): ")
height=input("Enter your meters(m): ")
bmi=float(weight)/float(height)**2
# Out:
# Enter your name: andrew
# Enter your weight(kg): 60
# Enter your meters(m): 1.73

# %%
print(name)
print(weight)
print(height)
print(bmi)
# Out:
# andrew
# 60
# 1.73
# 20.04744562130375

# %% [markdown]
# 6.

# %%
name=input("Enter your name: ")
weight=input("Enter your weight(kg): ")
height=input("Enter your meters(m): ")
bmi=float(weight)/float(height)**2
# Out:
# Enter your name: John Ray
# Enter your weight(kg): 60
# Enter your meters(m): 1.6764

# %%
print(name)
print(weight)
print(height)
print(bmi)
# Out:
# John Ray
# 60
# 1.6764
# 21.349904958763087

# %% [markdown]
# 6. Supplementary Activity:
